# %% [markdown]
# # Install and import libraries

# %%
# %pip install -q ibis-framework
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing the required libraries
import os
import ibis
import pandas as pd
import yaml
from typing import Dict, List

# %% [markdown]
# ## User Defined Variables

# %%
# Include the following tables
required_tables = ['vce_components_meta']
attr_datatypes = ['vce_datatype_lookup']

# %%
# Yaml file path
yaml_file_name = 'cc_db_class_info.yml'
yaml_file_path = os.path.join(os.getcwd(), yaml_file_name)

print(f"Yaml file path: {yaml_file_path}")
# Out:
# Yaml file path: /workspaces/coaching-companion/cc_db_class_info.yml

# %%
# Required Dictionaries

attr_dict = {} # Attribute dictionary (becomes a dict of dicts)
datatype_dict = {} # Data type dictionary (becomes a list of dicts)

# %% [markdown]
# # Functions to Access Data in the Database
# ## Connection Functions
# ### Establish the connection to the database

# %%
# Establish Connection to the Development Database
def gen_connection():
    conn = ibis.postgres.connect(
        host=os.environ['POSTGRES_DB_HOST'],
        user=os.environ['POSTGRES_DB_USER'],
        password=os.environ['POSTGRES_DB_PASSWORD'],
        database=os.environ['POSTGRES_DB_NAME']
    )
    return conn

# %% [markdown]
# ## Query Functions
# ### Access the Table Data

# %%
# Get Table
def get_table(table_name, conn = gen_connection()):
    return conn.table(table_name)

# %% [markdown]
# ### Access the Table Columns

# %%
# Get Table Columns
def get_table_columns(table_name, conn = gen_connection()) -> List[str]:
    table = get_table(table_name, conn)
    return table.columns

# %% [markdown]
# ### List the Table Data

# %%
# List Tables
def list_tables(conn = gen_connection()) -> List[str]:
    return conn.list_tables()

# %% [markdown]
# ### Extract the Classes Data

# %%
# Extract Classes
def extract_classes(conn_table,column:str = 'meta_value') -> List[str]:
    # Used when joining the same table
    a = conn_table.alias('a') # Add alias for table a
    b = conn_table.alias('b') # Add alias for table b

    # Perform the join with conditions
    joined = a.join(b, [a.component_id == b.component_id,
                        b.meta_key == 'type',
                        ~a.meta_key.like('lms_assignment_id%')])
    query = joined[b.meta_value].distinct()
    result = query.execute()
    
    return result[column].tolist()

# %% [markdown]
# ### Extract the Attributes and Datatypes

# %%
def extract_attr_datatypes(conn_table1,conn_table2) -> pd.DataFrame:
    # Aliases for readability
    a = conn_table1.alias('a')
    b = conn_table1.alias('b')
    c = conn_table1.alias('c')
    d = conn_table2.alias('d')

    joined = a.join(b, a.component_id == b.component_id) \
                .join(d, b.meta_key == d.type) \
                .join(c, [a.component_id == c.component_id,
                            c.meta_key == 'type',
                            c.meta_value == 'AWSDashboard',
                            ~a.meta_key.like('lms_assignment_id%')])

    query = joined[[b.meta_key, d.datatype]].distinct()
    result = query.execute()

    return result

# %% [markdown]
# ## Dictionary Functions
# ### Generate List of Datatype Dictionaries

# %%
def list_of_dicts(input_dataframe: pd.DataFrame, column_name_key: str, column_name_value: str) -> List[Dict[str, str]]:
    list_of_datatypes = [{row[column_name_key]: row[column_name_value]} for index, row in input_dataframe.iterrows()]
    return list_of_datatypes

# %% [markdown]
# ### Generate Dictionary Hierarchies

# %%
def nested_dict(new_dict: Dict, value_dict: Dict, key) -> Dict:
    new_dict[key] = value_dict
    return new_dict

# %% [markdown]
# ## Yaml Functions
# ### Create/Load the YAML File

# %%
def load_yaml(file_path):
    with open(file_path, 'r') as file:
        return yaml.safe_load(file)

# %% [markdown]
# ### Write the YAML File

# %%
def write_yaml(file_path, data):
    with open(file_path, 'w') as file:
        yaml.dump(data, file)

# %% [markdown]
# ## Extract Database Class Data and Move to Yaml File

# %%
# Establish Connection to the Development Database
try:
    conn = gen_connection()
    print("Connection to the database established.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Connection to the database established.

# %%
# Verify the required tables exist in the database
tables = list_tables(conn)

if set(required_tables).issubset(set(tables)):
    print(f"All required tables found in the database.")
else:
    print(f"Table {required_tables} not found in the database.")

if set(attr_datatypes).issubset(set(tables)):
    print(f"All attribute/datatype tables found in the database.")
else:
    print(f"Table {attr_datatypes} not found in the database.")
# Out:
# All required tables found in the database.
# All attribute/datatype tables found in the database.

# %%
# Loop over the required tables within the database and extract the necessary information
for i in range(len(required_tables)):

    # Initialize the dictionaries
    table_dict = {} # Table dictionary (becomes a dict of dicts)

    # Loop over the required tables
    vce_components_meta = get_table(required_tables[i],conn)
    if len(attr_datatypes) == 1:
        vce_datatype_lookup = get_table(attr_datatypes[0],conn)
    else:
        vce_datatype_lookup = get_table(attr_datatypes[i],conn)

    # Initialize the dictionaries
    class_dict = {} # Class dictionary (becomes a dict of dicts)
    # Extract the classes
    classes = extract_classes(vce_components_meta)

    # Loop over the classes
    for j in range(len(classes)):
        # Initialize the dictionaries
        attr_dict = {} # Attribute dictionary (becomes a dict of dicts)
        datatype_dict = {} # Data type dictionary (becomes a list of dicts)

        # Extract the attributes and datatypes
        attr_datatypes = extract_attr_datatypes(vce_components_meta,vce_datatype_lookup)
        
        # Loop over the attributes
        for k in range(len(attr_datatypes)):
            # Generate the list of dictionaries
            datatype_dict = list_of_dicts(attr_datatypes,'meta_key','datatype')
            # # Generate the nested dictionary
            # attr_dict = nested_dict(attr_dict,datatype_dict,attr_datatypes[k])
            
        # Generate the nested dictionary
        class_dict = nested_dict(class_dict,datatype_dict,classes[j])
        print(f"Class dictionary added the {classes[j]} class contents")

    # Create the new table in the dictionary
    table_dict = nested_dict(table_dict,class_dict,required_tables[i])
    print(f"Table dictionary added the {required_tables[i]} table contents")
# Out:
# Class dictionary added the Access class contents
# Class dictionary added the AccreditationCertificate class contents
# Class dictionary added the AccreditationSubmission class contents
# Class dictionary added the ActionPlans class contents
# Class dictionary added the AddPlayByPlay class contents
# Class dictionary added the Alias class contents
# Class dictionary added the Annotations class contents
# Class dictionary added the AssessmentsClassroom class contents
# Class dictionary added the AssessmentsDashbaord class contents
# Class dictionary added the AssessmentsEvaluation class contents
# Class dictionary added the AssessmentsLister class contents
# Class dictionary added the AssessmentsRating class contents
# Class dictionary added the AssessmentsReport class contents
# Class dictionary added the AssessmentsReportClassroom class contents
# Class dictionary added the AssessmentsSite class contents
# Class dictionary added the Assets class contents
# Class dictionary added the Assignments class contents
# Class dictionary added the AWSDashboard class contents
# Class dictionary added the CoachingPartnership class contents
# Class dictionary added the CollaboraEndpoint class contents
# Class dictionary added the Comments class contents
# Class dictionary added the ConnectToMerit class contents
# Class dictionary added the ContactForm class contents
# Class dictionary added the CopAssets class contents
# Class dictionary added the CopGroups class contents
# Class dictionary added the CopLocation class contents
# Class dictionary added the CoursesState class contents
# Class dictionary added the CycleDashboard class contents
# Class dictionary added the DiscussionBoards class contents
# Class dictionary added the DiscussionTopics class contents
# Class dictionary added the Documentation class contents
# Class dictionary added the DualLanguageHandbook class contents
# Class dictionary added the DualLanguageSubmission class contents
# Class dictionary added the Ea_eval_survey class contents
# Class dictionary added the Endpoint class contents
# Class dictionary added the FamilySurveyLink class contents
# Class dictionary added the Grade class contents
# Class dictionary added the Inquisitor class contents
# Class dictionary added the InstructorMaterials class contents
# Class dictionary added the Item class contents
# Class dictionary added the Layout class contents
# Class dictionary added the Limit class contents
# Class dictionary added the Links class contents
# Class dictionary added the Lister class contents
# Class dictionary added the Location class contents
# Class dictionary added the Login class contents
# Class dictionary added the Logout class contents
# Class dictionary added the LtiEndpoint class contents
# Class dictionary added the ManageComponents class contents
# Class dictionary added the ManageDatalists class contents
# Class dictionary added the ManageGroups class contents
# Class dictionary added the ManageMenus class contents
# Class dictionary added the ManageRecipes class contents
# Class dictionary added the ManageSite class contents
# Class dictionary added the ManageStudents class contents
# Class dictionary added the ManageUsers class contents
# Class dictionary added the Media class contents
# Class dictionary added the MediaDatabase class contents
# Class dictionary added the MeritEndpoint class contents
# Class dictionary added the MssqlServer class contents
# Class dictionary added the Note class contents
# Class dictionary added the ProgramProfileSubmission class contents
# Class dictionary added the RatingsRubric class contents
# Class dictionary added the RecordsReviewHandbook class contents
# Class dictionary added the RecordsReviewSubmission class contents
# Class dictionary added the ReflectionAssignment class contents
# Class dictionary added the Reports class contents
# Class dictionary added the ReportsBuilder class contents
# Class dictionary added the ResetPassword class contents
# Class dictionary added the ResourceLibrary class contents
# Class dictionary added the SharedAssets class contents
# Class dictionary added the SharedGoals class contents
# Class dictionary added the Solotron class contents
# Class dictionary added the StudentSubmissions class contents
# Class dictionary added the StudentSubmissionsSlug class contents
# Class dictionary added the SupportingDocumentation class contents
# Class dictionary added the Tagit class contents
# Class dictionary added the Tracker class contents
# Class dictionary added the UnassignedAssets class contents
# Class dictionary added the UploadAndReflectionAssignment class contents
# Class dictionary added the UserInvitations class contents
# Class dictionary added the UserSettings class contents
# Class dictionary added the UsersLogAllAttributes class contents
# Class dictionary added the UsersLogCompletedGoals class contents
# Class dictionary added the UsersLogCopGroups class contents
# Class dictionary added the UsersLogCopGroupsDigest class contents
# Class dictionary added the UsersLogCreatedAt class contents
# Class dictionary added the UsersLogPartnerships class contents
# Class dictionary added the UsersLogProperties class contents
# Class dictionary added the UsersLogReporting class contents
# Class dictionary added the UsersLogSharedGoals class contents
# Class dictionary added the UsersLogUploads class contents
# Class dictionary added the UserSubmissions class contents
# Class dictionary added the VideoConference class contents
# Class dictionary added the VideoHighlightSubmission class contents
# Class dictionary added the VideoReflection class contents
# Table dictionary added the vce_components_meta table contents

# %%
# Verify contents of the table dictionary
print("The table dictionary is as follows:")
print(yaml.dump(table_dict))
# Out:
# The table dictionary is as follows:
# vce_components_meta:
#   AWSDashboard:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Access:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   AccreditationCertificate:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   AccreditationSubmission:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ActionPlans:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   AddPlayByPlay:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Alias:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Annotations:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   AssessmentsClassroom:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   AssessmentsDashbaord:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   AssessmentsEvaluation:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   AssessmentsLister:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   AssessmentsRating:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   AssessmentsReport:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   AssessmentsReportClassroom:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   AssessmentsSite:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Assets:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Assignments:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   CoachingPartnership:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   CollaboraEndpoint:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Comments:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ConnectToMerit:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ContactForm:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   CopAssets:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   CopGroups:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   CopLocation:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   CoursesState:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   CycleDashboard:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   DiscussionBoards:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   DiscussionTopics:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Documentation:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   DualLanguageHandbook:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   DualLanguageSubmission:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Ea_eval_survey:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Endpoint:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   FamilySurveyLink:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Grade:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Inquisitor:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   InstructorMaterials:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Item:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Layout:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Limit:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Links:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Lister:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Location:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Login:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Logout:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   LtiEndpoint:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ManageComponents:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ManageDatalists:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ManageGroups:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ManageMenus:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ManageRecipes:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ManageSite:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ManageStudents:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ManageUsers:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Media:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   MediaDatabase:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   MeritEndpoint:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   MssqlServer:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Note:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ProgramProfileSubmission:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   RatingsRubric:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   RecordsReviewHandbook:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   RecordsReviewSubmission:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ReflectionAssignment:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Reports:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ReportsBuilder:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ResetPassword:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   ResourceLibrary:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   SharedAssets:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   SharedGoals:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Solotron:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   StudentSubmissions:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   StudentSubmissionsSlug:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   SupportingDocumentation:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Tagit:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   Tracker:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UnassignedAssets:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UploadAndReflectionAssignment:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UserInvitations:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UserSettings:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UserSubmissions:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UsersLogAllAttributes:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UsersLogCompletedGoals:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UsersLogCopGroups:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UsersLogCopGroupsDigest:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UsersLogCreatedAt:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UsersLogPartnerships:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UsersLogProperties:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UsersLogReporting:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UsersLogSharedGoals:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   UsersLogUploads:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   VideoConference:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   VideoHighlightSubmission:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)
#   VideoReflection:
#   - created_by: int
#   - created_at: unix timestamp
#   - title: varchar(255)
#   - type: varchar(50)

# %%
# Write the dictionary to a yaml file
write_yaml(yaml_file_path,table_dict)
print(f"Yaml file written to {yaml_file_path}")
# Out:
# Yaml file written to /workspaces/coaching-companion/cc_db_class_info.yml
