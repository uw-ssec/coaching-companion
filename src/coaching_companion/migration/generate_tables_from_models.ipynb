# %% [markdown]
# # Migration Script
# This script is used to migrate nested data from one database into new tables within the same database. The script is written in Python and uses [SQLModel](https://sqlmodel.tiangolo.com/) to create, validate, and interact with the database.

# %% [markdown]
# ## Create Database Tables
# ### Import Packages

# %%
import os
from coaching_companion.models import *
from sqlalchemy import create_engine, URL
from sqlmodel import SQLModel, create_engine

# %% [markdown]
# ### Create Database Connection

# %%
# Generate the URL object
url_object = os.environ["PG_TEST_URL_OBJECT"]

# Create the engine
engine = create_engine(url_object, echo=True)
# print(engine)

# Reference: https://docs.sqlalchemy.org/en/20/core/engines.html

# %% [markdown]
# ### Create Database Tables

# %%
# Verify presence of the auth_user table
SQLModel.metadata.tables['public.auth_user']
# Out:
# Table('auth_user', MetaData(), Column('id', Integer(), table=<auth_user>, primary_key=True, nullable=False), Column('password', AutoString(length=128), table=<auth_user>, nullable=False), Column('last_login', AutoString(), table=<auth_user>, nullable=False), Column('is_superuser', Boolean(), table=<auth_user>, nullable=False), Column('username', AutoString(length=255), table=<auth_user>, nullable=False), Column('email', AutoString(length=255), table=<auth_user>, nullable=False), Column('is_verified', Boolean(), table=<auth_user>, nullable=False), Column('is_active', Boolean(), table=<auth_user>, nullable=False), Column('is_staff', Boolean(), table=<auth_user>, nullable=False), Column('created_at', Text(), table=<auth_user>, nullable=False), Column('updated_at', Text(), table=<auth_user>, nullable=False), Column('first_name', AutoString(length=255), table=<auth_user>, nullable=False), Column('nestor_user_id', Integer(), table=<auth_user>, nullable=False), Column('last_name', AutoString(length=255), table=<auth_user>, nullable=False), schema='public')

# %%
# Create the Database Tables based on Validation Models
SQLModel.metadata.create_all(engine)
# Out:
# 2024-09-05 20:48:10,497 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2024-09-05 20:48:10,497 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-09-05 20:48:10,523 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-09-05 20:48:10,523 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-09-05 20:48:10,549 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2024-09-05 20:48:10,549 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-09-05 20:48:10,574 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-05 20:48:10,578 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,579 INFO sqlalchemy.engine.Engine [generated in 0.00087s] {'table_name': 'auth_user', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,606 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,606 INFO sqlalchemy.engine.Engine [cached since 0.02818s ago] {'table_name': 'aws_dashboard', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,620 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,620 INFO sqlalchemy.engine.Engine [cached since 0.04168s ago] {'table_name': 'access', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,633 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,634 INFO sqlalchemy.engine.Engine [cached since 0.0559s ago] {'table_name': 'accreditation_certificate', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,647 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,648 INFO sqlalchemy.engine.Engine [cached since 0.06962s ago] {'table_name': 'action_plans', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,661 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,661 INFO sqlalchemy.engine.Engine [cached since 0.08312s ago] {'table_name': 'add_play_by_play', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,675 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,675 INFO sqlalchemy.engine.Engine [cached since 0.09677s ago] {'table_name': 'alias', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,689 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,689 INFO sqlalchemy.engine.Engine [cached since 0.1107s ago] {'table_name': 'annotations', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,702 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,703 INFO sqlalchemy.engine.Engine [cached since 0.1242s ago] {'table_name': 'assessments_classroom', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,716 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,716 INFO sqlalchemy.engine.Engine [cached since 0.1378s ago] {'table_name': 'assessments_dashboard', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,729 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,730 INFO sqlalchemy.engine.Engine [cached since 0.1512s ago] {'table_name': 'assessments_evaluation', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,742 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,743 INFO sqlalchemy.engine.Engine [cached since 0.1645s ago] {'table_name': 'assessments_lister', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,756 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,756 INFO sqlalchemy.engine.Engine [cached since 0.1777s ago] {'table_name': 'assessments_rating', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,770 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,770 INFO sqlalchemy.engine.Engine [cached since 0.1916s ago] {'table_name': 'assessments_report', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,783 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,783 INFO sqlalchemy.engine.Engine [cached since 0.205s ago] {'table_name': 'assessments_report_classroom', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,796 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,797 INFO sqlalchemy.engine.Engine [cached since 0.2184s ago] {'table_name': 'assessments_site', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,810 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,810 INFO sqlalchemy.engine.Engine [cached since 0.232s ago] {'table_name': 'assets', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,824 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,824 INFO sqlalchemy.engine.Engine [cached since 0.2457s ago] {'table_name': 'assignments', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,837 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,837 INFO sqlalchemy.engine.Engine [cached since 0.259s ago] {'table_name': 'coaching_partnership', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,851 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,851 INFO sqlalchemy.engine.Engine [cached since 0.273s ago] {'table_name': 'collabora_endpoint', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,865 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,865 INFO sqlalchemy.engine.Engine [cached since 0.2868s ago] {'table_name': 'comments', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,878 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,878 INFO sqlalchemy.engine.Engine [cached since 0.3001s ago] {'table_name': 'connect_to_merit', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,891 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,892 INFO sqlalchemy.engine.Engine [cached since 0.3134s ago] {'table_name': 'contact_form', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,905 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,905 INFO sqlalchemy.engine.Engine [cached since 0.3266s ago] {'table_name': 'cop_assets', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,918 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,918 INFO sqlalchemy.engine.Engine [cached since 0.3398s ago] {'table_name': 'cop_groups', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,931 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,932 INFO sqlalchemy.engine.Engine [cached since 0.3534s ago] {'table_name': 'cop_location', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,945 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,945 INFO sqlalchemy.engine.Engine [cached since 0.3667s ago] {'table_name': 'courses_state', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,958 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,958 INFO sqlalchemy.engine.Engine [cached since 0.38s ago] {'table_name': 'cycle_dashboard', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,972 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,972 INFO sqlalchemy.engine.Engine [cached since 0.3937s ago] {'table_name': 'discussion_boards', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,985 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,985 INFO sqlalchemy.engine.Engine [cached since 0.407s ago] {'table_name': 'discussion_topics', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:10,999 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:10,999 INFO sqlalchemy.engine.Engine [cached since 0.4205s ago] {'table_name': 'documentation', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,012 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,012 INFO sqlalchemy.engine.Engine [cached since 0.4339s ago] {'table_name': 'dual_language_handbook', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,025 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,026 INFO sqlalchemy.engine.Engine [cached since 0.4473s ago] {'table_name': 'dual_language_submission', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,039 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,039 INFO sqlalchemy.engine.Engine [cached since 0.4608s ago] {'table_name': 'ea_eval_survey', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,052 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,053 INFO sqlalchemy.engine.Engine [cached since 0.4747s ago] {'table_name': 'endpoint', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,066 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,066 INFO sqlalchemy.engine.Engine [cached since 0.488s ago] {'table_name': 'family_survey_link', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,079 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,080 INFO sqlalchemy.engine.Engine [cached since 0.5018s ago] {'table_name': 'grade', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,094 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,094 INFO sqlalchemy.engine.Engine [cached since 0.5157s ago] {'table_name': 'inquisitor', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,107 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,107 INFO sqlalchemy.engine.Engine [cached since 0.529s ago] {'table_name': 'instructor_materials', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,123 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,124 INFO sqlalchemy.engine.Engine [cached since 0.5454s ago] {'table_name': 'item', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,137 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,137 INFO sqlalchemy.engine.Engine [cached since 0.5588s ago] {'table_name': 'layout', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,150 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,150 INFO sqlalchemy.engine.Engine [cached since 0.572s ago] {'table_name': 'limit', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,164 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,164 INFO sqlalchemy.engine.Engine [cached since 0.5859s ago] {'table_name': 'links', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,177 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,177 INFO sqlalchemy.engine.Engine [cached since 0.5992s ago] {'table_name': 'lister', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,190 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,191 INFO sqlalchemy.engine.Engine [cached since 0.6124s ago] {'table_name': 'location', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,204 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,204 INFO sqlalchemy.engine.Engine [cached since 0.6258s ago] {'table_name': 'login', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,217 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,217 INFO sqlalchemy.engine.Engine [cached since 0.639s ago] {'table_name': 'logout', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,230 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,231 INFO sqlalchemy.engine.Engine [cached since 0.6522s ago] {'table_name': 'lti_endpoint', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,243 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,244 INFO sqlalchemy.engine.Engine [cached since 0.6654s ago] {'table_name': 'manage_components', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,256 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,257 INFO sqlalchemy.engine.Engine [cached since 0.6784s ago] {'table_name': 'manage_datalists', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,270 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,270 INFO sqlalchemy.engine.Engine [cached since 0.6916s ago] {'table_name': 'manage_groups', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,283 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,283 INFO sqlalchemy.engine.Engine [cached since 0.7048s ago] {'table_name': 'manage_menus', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,297 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,297 INFO sqlalchemy.engine.Engine [cached since 0.7189s ago] {'table_name': 'manage_recipes', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,310 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,311 INFO sqlalchemy.engine.Engine [cached since 0.7323s ago] {'table_name': 'manage_site', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,324 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,324 INFO sqlalchemy.engine.Engine [cached since 0.7457s ago] {'table_name': 'manage_students', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,337 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,337 INFO sqlalchemy.engine.Engine [cached since 0.7591s ago] {'table_name': 'manage_users', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,350 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,351 INFO sqlalchemy.engine.Engine [cached since 0.7723s ago] {'table_name': 'media', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,364 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,364 INFO sqlalchemy.engine.Engine [cached since 0.786s ago] {'table_name': 'media_database', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,377 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,378 INFO sqlalchemy.engine.Engine [cached since 0.7997s ago] {'table_name': 'merit_endpoint', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,391 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,392 INFO sqlalchemy.engine.Engine [cached since 0.8136s ago] {'table_name': 'mssql_server', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,406 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,408 INFO sqlalchemy.engine.Engine [cached since 0.8293s ago] {'table_name': 'note', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,421 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,422 INFO sqlalchemy.engine.Engine [cached since 0.8434s ago] {'table_name': 'program_profile_submission', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,435 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,436 INFO sqlalchemy.engine.Engine [cached since 0.8579s ago] {'table_name': 'ratings_rubric', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,449 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,450 INFO sqlalchemy.engine.Engine [cached since 0.8714s ago] {'table_name': 'records_review_handbook', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,463 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,463 INFO sqlalchemy.engine.Engine [cached since 0.8848s ago] {'table_name': 'records_review_submission', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,476 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,476 INFO sqlalchemy.engine.Engine [cached since 0.8981s ago] {'table_name': 'reflection_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,489 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,490 INFO sqlalchemy.engine.Engine [cached since 0.9114s ago] {'table_name': 'reports', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,503 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,503 INFO sqlalchemy.engine.Engine [cached since 0.9247s ago] {'table_name': 'reports_builder', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,516 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,516 INFO sqlalchemy.engine.Engine [cached since 0.9379s ago] {'table_name': 'reset_password', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,529 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,530 INFO sqlalchemy.engine.Engine [cached since 0.9519s ago] {'table_name': 'resource_library', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,543 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,544 INFO sqlalchemy.engine.Engine [cached since 0.9658s ago] {'table_name': 'shared_assets', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,557 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,558 INFO sqlalchemy.engine.Engine [cached since 0.9792s ago] {'table_name': 'shared_goals', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,571 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,571 INFO sqlalchemy.engine.Engine [cached since 0.993s ago] {'table_name': 'solotron', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# 2024-09-05 20:48:11,584 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2024-09-05 20:48:11,585 INFO sqlalchemy.engine.Engine [cached since 1.006s ago] {'table_name': 'student_submissions', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'public'}
# ...
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,345 INFO sqlalchemy.engine.Engine [no key 0.00039s] {}
# 2024-09-05 20:48:13,371 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.program_profile_submission (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,371 INFO sqlalchemy.engine.Engine [no key 0.00047s] {}
# 2024-09-05 20:48:13,397 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.ratings_rubric (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,398 INFO sqlalchemy.engine.Engine [no key 0.00037s] {}
# 2024-09-05 20:48:13,418 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.records_review_handbook (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,418 INFO sqlalchemy.engine.Engine [no key 0.00034s] {}
# 2024-09-05 20:48:13,440 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.records_review_submission (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,440 INFO sqlalchemy.engine.Engine [no key 0.00094s] {}
# 2024-09-05 20:48:13,461 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.reflection_assignment (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	assignment_category VARCHAR(15) NOT NULL,
# 	components_limit INTEGER NOT NULL,
# 	instructions TEXT NOT NULL,
# 	recipe_key INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,462 INFO sqlalchemy.engine.Engine [no key 0.00049s] {}
# 2024-09-05 20:48:13,488 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.reports (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	report_types VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,489 INFO sqlalchemy.engine.Engine [no key 0.00053s] {}
# 2024-09-05 20:48:13,510 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.reports_builder (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	recipe VARCHAR(255) NOT NULL,
# 	report_types VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,510 INFO sqlalchemy.engine.Engine [no key 0.00045s] {}
# 2024-09-05 20:48:13,537 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.reset_password (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	recipe VARCHAR(255) NOT NULL,
# 	template VARCHAR(100) NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,537 INFO sqlalchemy.engine.Engine [no key 0.00043s] {}
# 2024-09-05 20:48:13,563 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.resource_library (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,563 INFO sqlalchemy.engine.Engine [no key 0.00039s] {}
# 2024-09-05 20:48:13,585 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.shared_assets (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	template VARCHAR(100) NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,585 INFO sqlalchemy.engine.Engine [no key 0.00054s] {}
# 2024-09-05 20:48:13,605 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.shared_goals (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	completed_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	core_knowledge_categories VARCHAR(100) NOT NULL,
# 	cycle_summary TEXT NOT NULL,
# 	info TEXT NOT NULL,
# 	prototype_id UUID NOT NULL,
# 	status VARCHAR(20) NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,605 INFO sqlalchemy.engine.Engine [no key 0.00040s] {}
# 2024-09-05 20:48:13,631 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.solotron (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	can_survey_components VARCHAR(150) NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,632 INFO sqlalchemy.engine.Engine [no key 0.00046s] {}
# 2024-09-05 20:48:13,652 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.student_submissions (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,652 INFO sqlalchemy.engine.Engine [no key 0.00046s] {}
# 2024-09-05 20:48:13,672 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.student_submissions_slug (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,673 INFO sqlalchemy.engine.Engine [no key 0.00053s] {}
# 2024-09-05 20:48:13,693 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.supporting_documentation (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,694 INFO sqlalchemy.engine.Engine [no key 0.00049s] {}
# 2024-09-05 20:48:13,714 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.tagit (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	timestamp TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,715 INFO sqlalchemy.engine.Engine [no key 0.00049s] {}
# 2024-09-05 20:48:13,735 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.tracker (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	description TEXT NOT NULL,
# 	template VARCHAR(100) NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,736 INFO sqlalchemy.engine.Engine [no key 0.00067s] {}
# 2024-09-05 20:48:13,762 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.unassigned_assets (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	template VARCHAR(100) NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,763 INFO sqlalchemy.engine.Engine [no key 0.00042s] {}
# 2024-09-05 20:48:13,784 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.upload_and_reflection_assignment (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	assignment_category VARCHAR(15) NOT NULL,
# 	components_limit INTEGER NOT NULL,
# 	grading_rubric TEXT NOT NULL,
# 	instructions TEXT NOT NULL,
# 	recipe_key INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,785 INFO sqlalchemy.engine.Engine [no key 0.00052s] {}
# 2024-09-05 20:48:13,811 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_invitations (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	recipe VARCHAR(255) NOT NULL,
# 	template VARCHAR(100) NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,811 INFO sqlalchemy.engine.Engine [no key 0.00047s] {}
# 2024-09-05 20:48:13,838 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_settings (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	recipe VARCHAR(255) NOT NULL,
# 	recipe_name VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,839 INFO sqlalchemy.engine.Engine [no key 0.00076s] {}
# 2024-09-05 20:48:13,866 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_submissions (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	recipe VARCHAR(255) NOT NULL,
# 	can_view VARCHAR(150) NOT NULL,
# 	repudiated_url TEXT NOT NULL,
# 	can_submit VARCHAR(150) NOT NULL,
# 	content_administrator VARCHAR(10) NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,867 INFO sqlalchemy.engine.Engine [no key 0.00055s] {}
# 2024-09-05 20:48:13,894 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_log_all_attributes (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,894 INFO sqlalchemy.engine.Engine [no key 0.00088s] {}
# 2024-09-05 20:48:13,915 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_log_completed_goals (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,915 INFO sqlalchemy.engine.Engine [no key 0.00053s] {}
# 2024-09-05 20:48:13,937 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_log_cop_groups (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,937 INFO sqlalchemy.engine.Engine [no key 0.00032s] {}
# 2024-09-05 20:48:13,957 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_log_cop_groups_digest (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,958 INFO sqlalchemy.engine.Engine [no key 0.00050s] {}
# 2024-09-05 20:48:13,978 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_log_created_at (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:13,978 INFO sqlalchemy.engine.Engine [no key 0.00038s] {}
# 2024-09-05 20:48:14,006 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_log_partnerships (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:14,007 INFO sqlalchemy.engine.Engine [no key 0.00051s] {}
# 2024-09-05 20:48:14,028 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_log_properties (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:14,028 INFO sqlalchemy.engine.Engine [no key 0.00039s] {}
# 2024-09-05 20:48:14,050 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_log_reporting (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:14,050 INFO sqlalchemy.engine.Engine [no key 0.00047s] {}
# 2024-09-05 20:48:14,071 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_log_shared_goals (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:14,071 INFO sqlalchemy.engine.Engine [no key 0.00043s] {}
# 2024-09-05 20:48:14,092 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.user_log_uploads (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:14,092 INFO sqlalchemy.engine.Engine [no key 0.00050s] {}
# 2024-09-05 20:48:14,113 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.video_conference (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:14,113 INFO sqlalchemy.engine.Engine [no key 0.00037s] {}
# 2024-09-05 20:48:14,133 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.video_highlight_submission (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:14,134 INFO sqlalchemy.engine.Engine [no key 0.00060s] {}
# 2024-09-05 20:48:14,155 INFO sqlalchemy.engine.Engine
# CREATE TABLE public.video_reflection (
# 	id SERIAL NOT NULL,
# 	created_at TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	created_by BIGINT NOT NULL,
# 	title VARCHAR(255) NOT NULL,
# 	type_ VARCHAR(50),
# 	"idClassroom" UUID NOT NULL,
# 	"idRating" UUID NOT NULL,
# 	"idVHResponse" UUID NOT NULL,
# 	parent_url TEXT NOT NULL,
# 	procedure VARCHAR(20) NOT NULL,
# 	ratings_id UUID NOT NULL,
# 	reflection_input TEXT NOT NULL,
# 	updated_on TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(created_by) REFERENCES public.auth_user (id)
# )
#
#
# 2024-09-05 20:48:14,156 INFO sqlalchemy.engine.Engine [no key 0.00091s] {}
# 2024-09-05 20:48:14,182 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Delete Database Tables

# %%
# Delete the Database Tables based on Validation Models
# NOTE: This will delete all data in the tables (but not tables with dependencies like the auth_user table)
# SQLModel.metadata.drop_all(engine) # DO NOT CASCADE DROP ALL
